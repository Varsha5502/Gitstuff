# %% [markdown]
# # Data Cleaning with Pandas
#
# *This notebook was adapted from Melanie Walsh's "Pandas Basics", [Part 3](https://melaniewalsh.github.io/Intro-Cultural-Analytics/03-Data-Analysis/03-Pandas-Basics-Part3.html#) and [Part 4](https://melaniewalsh.github.io/Intro-Cultural-Analytics/03-Data-Analysis/04-Pandas-Merge-Datasets.html).*
#
# In this notebook, we will expand our knowledge of pandas by discussing the following aspects of data cleaning:
#
# - Merging datasets
# - More on the dataframe `index`
# - Intro to accessor functions (e.g., working with strings, datetimes, etc.)
# - Applying functions
# - `map`, `reduce`, and `filter`
# - The `.apply` method
# - `pivot` and `melt`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt                 
import seaborn as sns

# %config InlineBackend.figure_formats = ['svg']

# personal seaborn preferences ...
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="whitegrid", rc=custom_params)

# %% [markdown]
# ## Diversity in Film

# %% [markdown]
# **How many movies are actually dispropotionately featuring white men? What changes by genre, era, or box-office revenue? What circumstances generate more diversity?**
#
# The dataset that we're working with in this lesson is taken from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). The dataset provides information about 2,000 films from 1925 to 2015, including characters’ names, genders, ages, how many words each character spoke in each film, the release year of each film, and how much money the film grossed. They included character gender information because they wanted to contribute data to a broader conversation about how "white men dominate movie roles."
#
# Yet, transforming complex social constructs like gender into quantifiable data is tricky and historically fraught. They claim, in fact, that one of the [most frequently asked questions](https://medium.com/@matthew_daniels/faq-for-the-film-dialogue-by-gender-project-40078209f751) about the piece is about gender: E.g., *“How do you know the monster in Monsters Inc. is a boy!"* The short answer is that they don't. To determine character gender, they used actors' IMDB information, which they acknowledge is an imperfect approach: "Sometimes, women voice male characters. Bart Simpson, for example, is voiced by a woman. We’re aware that this means some of the data is wrong, AND we’re still fine with the methodology and approach."
#
# > **What do you think about this approach to determining gender?** How does such a binary understanding of gender, gleaned from the IMDB pages of actors, influence our later results and conclusions? What do we gain by using such an approach, and what do we lose? How else might we have encoded or determined gender for the same data?

# %% [markdown]
# ## Merging
#
# When Andersen and Daniels published their essay, they used results from *two* related data tables. Before we proceed in this notebook, we'll merge the two.

# %%
df_metadata = pd.read_csv('./data/meta_data7.csv')
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   script_id   2000 non-null   int64
#  1   imdb_id     2000 non-null   object
#  2   title       2000 non-null   object
#  3   year        2000 non-null   int64
#  4   gross       1662 non-null   float64
#  5   lines_data  2000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 93.9+ KB

# %%
df_metadata.head()
# Out:
#    script_id    imdb_id                       title  year  gross  \
# 0       1534  tt1022603        (500) Days of Summer  2009   37.0
# 1       1512  tt0147800  10 Things I Hate About You  1999   65.0
# 2       1514  tt0417385              12 and Holding  2005    NaN
# 3       1517  tt2024544            12 Years a Slave  2013   60.0
# 4       1520  tt1542344                   127 Hours  2010   20.0
#
#                                           lines_data
# 0  7435445256774780000000000000000000000000000000...
# 1  1777752320274530000000000000000000000000000000...
# 2  5461357777754220000000000000000000000000000000...
# 3  4567334777777780000000000000000000000000000000...
# 4                     453513352345766000000000000000

# %% [markdown]
# The "lines_data" column apparently contains encoded information about when during the film each character speaks. Since we don't have the means (or need) to decode it, we'll drop the column altogether.

# %%
df_metadata.drop(columns='lines_data', inplace=True)

# %% [markdown]
# They published another CSV file called "character_list5.csv" that contains, among other things, the name, gender, and age of each character as well as the number of words the character speaks.

# %%
df_characters = pd.read_csv('./data/character_list5.csv')
df_characters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23048 entries, 0 to 23047
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   script_id            23048 non-null  int64
#  1   imdb_character_name  23046 non-null  object
#  2   words                23048 non-null  int64
#  3   gender               23048 non-null  object
#  4   age                  18263 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 900.4+ KB

# %%
df_characters
# Out:
#        script_id imdb_character_name  words gender   age
# 0            280               betty    311      f  35.0
# 1            280     carolyn johnson    873      f   NaN
# 2            280             eleanor    138      f   NaN
# 3            280     francesca johns   2251      f  46.0
# 4            280               madge    190      f  46.0
# ...          ...                 ...    ...    ...   ...
# 23043       9254             lumiere   1063      m  56.0
# 23044       9254             maurice   1107      m  71.0
# 23045       9254     monsieur d'arqu    114      m  58.0
# 23046       9254          mrs. potts    564      f  66.0
# 23047       9254            wardrobe    121      f  54.0
#
# [23048 rows x 5 columns]

# %% [markdown]
# As you can see, the characters DataFrame doesn't include the actual title of the movie in which the character appears or the movie's release year or box office gross. And `df_metadata` doesn't contain any information about the characters. We want that info all in one place.

# %% [markdown]
# There's one column that both datasets share in common: *script_id*. If two datasets share at least one column in common, we can merge them together based on this column. Using the [`pd.merge()` function](https://pandas.pydata.org/docs/user_guide/merging.html#brief-primer-on-merge-methods-relational-algebra), we link each corresponding row carying the same *script_id* value. As explained in the linked documentation, this could be **one-to-one**, **one-to-many**, or **many-to-many**. For example:
#
#     Column values [1,2,3,4,5] merged with [6,7,8,9,10] will give 0 rows
#     Column values [1,2,3,4,5] merged with [1,2,3,4,5] will give 5 rows
#     Column values [1,1,1,1,1] merged with [1,1,1,1,1] will give 25 rows

# %%
df_a = pd.DataFrame({'a': [1, 2, 3, 4],
                     'letters_from_a': ['a', 'b', 'c', 'd']})

df_b = pd.DataFrame({'a': [2, 3, 4, 5, 6],
                     'letters_from_b': ['a', 'b', 'c', 'd', 'e']})

# %%
pd.merge(df_a, df_b, how='inner')  # try the other `how` options
# Out:
#    a letters_from_a letters_from_b
# 0  2              b              a
# 1  3              c              b
# 2  4              d              c

# %%
df_films = pd.merge(df_characters, df_metadata, on='script_id')

# %% [markdown]
# > What does each row represent now?

# %% [markdown]
# ### data check
# Running "data checks" or "gut checks" is just a good habit to get into, so I'll show an example here of gaining confidence that our merge went smoothly.

# %%
# validation check
df_characters.shape, df_metadata.shape
# Out:
# ((23048, 5), (2000, 5))

# %%
df_films.shape
# Out:
# (23048, 9)

# %%
df_films.sample(10)
# Out:
#        script_id imdb_character_name  words gender   age    imdb_id  \
# 12190       3970               tango   1288      m  45.0  tt1210042
# 20812       8025     doctor - vietna    147      m   NaN  tt0096969
# 4962        1892     detective green    321      m   NaN  tt0144117
# 4890        1872              angela    262      f   NaN  tt0082089
# 8538        2793                 ray    340      m  44.0  tt0116905
# 2886        1339                 ken    154      m   NaN  tt0208092
# 1225         921          bubba blue    475      m  37.0  tt0109830
# 17881       6605              audrey   1027      f  26.0  tt0364955
# 21499       8323                goro   1084      m  45.0  tt0073918
# 17041       6101              leiter    317      m  46.0  tt0070328
#
#                             title  year  gross
# 12190           Brooklyn's Finest  2009   31.0
# 20812  Born on the Fourth of July  1989  153.0
# 4962          The Boondock Saints  1999    NaN
# 4890                    Body Heat  1981    NaN
# 8538                    Lone Star  1996   26.0
# 2886                      Snatch.  2000   48.0
# 1225                 Forrest Gump  1994  686.0
# 17881     Art School Confidential  2006    4.0
# 21499                  The Yakuza  1974    NaN
# 17041            Live and Let Die  1973  174.0

# %% [markdown]
# We can use `.duplicated` to build a Boolean series which logs duplicate rows. Rows that *are* duplicated can be counted using `.sum`.

# %%
df_films.duplicated().sum()
# Out:
# 0

# %%
df_characters['age'].isna().sum() == df_films['age'].isna().sum()
# Out:
# True

# %%
# a bit of cleanup
df_films.rename(columns={'imdb_character_name': 'character', 
                         'year': 'release_year'}, inplace=True)

# %% [markdown]
# ## Minding the Index
#
# **The safest way to create new columns is with the `df` on both sides of the `=` sign.** It *is* possible to create a pandas Series "*outside*" of the original DataFrame, and the index will line up with the DataFrame in question, but this is not a good habit to get into, as it's not uncommon for indices to morph throughout your manipulation work.

# %%
df_ = pd.DataFrame({'a': [1, 2, 3, 4]})
df_
# Out:
#    a
# 0  1
# 1  2
# 2  3
# 3  4

# %%
series_ = pd.Series(index=[3, 1, 2], data=[5, 6, 7])

# %%
df_['series_'] = series_
df_
# Out:
#    a  series_
# 0  1      NaN
# 1  2      6.0
# 2  3      7.0
# 3  4      5.0

# %% [markdown]
# For example, let's start by looking at the total number of words and characters in each film.

# %%
df_title_words = df_films.groupby(['title']) \
                          .agg({'words': 'sum',
                                'character': 'nunique'}) \
                          .rename(columns = {"character": "n_characters"})
df_title_words
# Out:
#                             words  n_characters
# title
# (500) Days of Summer        18500            13
# 10 Things I Hate About You  19680            12
# 12 Years a Slave            19628            28
# 12 and Holding              15968            15
# 127 Hours                    5145             4
# ...                           ...           ...
# Zero Effect                 13927             7
# Zerophilia                  16686             8
# Zodiac                      14656            31
# eXistenZ                     9447             9
# xXx                          8285             9
#
# [1994 rows x 2 columns]

# %% [markdown]
# The `groupby` operation automatically assigns the "group" to the index because it is guaranteed to be unique.

# %% [markdown]
# ### Resetting the Index
#
# We could reset this if we like, as we typically will when we use `groupby`.

# %%
df_title_words.reset_index(inplace=True)
df_title_words
# Out:
#                            title  words  n_characters
# 0           (500) Days of Summer  18500            13
# 1     10 Things I Hate About You  19680            12
# 2               12 Years a Slave  19628            28
# 3                 12 and Holding  15968            15
# 4                      127 Hours   5145             4
# ...                          ...    ...           ...
# 1989                 Zero Effect  13927             7
# 1990                  Zerophilia  16686             8
# 1991                      Zodiac  14656            31
# 1992                    eXistenZ   9447             9
# 1993                         xXx   8285             9
#
# [1994 rows x 3 columns]

# %% [markdown]
# ### Setting the Index
#
# And we can reverse this by picking a column **with no duplicates** to be the index. <span style='color:darkred'>Note: pandas will not stop you from setting a column *with* duplicates as an index, so be careful.</span>

# %%
df_title_words.set_index('title')
# Out:
#                             words  n_characters
# title
# (500) Days of Summer        18500            13
# 10 Things I Hate About You  19680            12
# 12 Years a Slave            19628            28
# 12 and Holding              15968            15
# 127 Hours                    5145             4
# ...                           ...           ...
# Zero Effect                 13927             7
# Zerophilia                  16686             8
# Zodiac                      14656            31
# eXistenZ                     9447             9
# xXx                          8285             9
#
# [1994 rows x 2 columns]

# %% [markdown]
# ### groupby and transform
#
# Our data only contains the number of words a character spoke in a film, but supposing we want the proportion of words from the film, we'll need `groupby` and `transform`. This will be fine because the combination of `groupby` and `transform` will return a dataframe with the same index as our data frame.

# %%
# intermediate step ... this index should match that of `df_films`
title_word_totals = df_films.groupby(['title'])['words'].transform('sum')

# %%
df_films['proportion_of_dialogue'] = df_films['words'] / title_word_totals

# %%
df_films[['title', 'words', 'proportion_of_dialogue']].sort_values('title')
# Out:
#                      title  words  proportion_of_dialogue
# 3700  (500) Days of Summer    134                0.007243
# 3709  (500) Days of Summer    600                0.032432
# 3708  (500) Days of Summer   8938                0.483135
# 3707  (500) Days of Summer   4080                0.220541
# 3706  (500) Days of Summer    112                0.006054
# ...                    ...    ...                     ...
# 3552                   xXx   1189                0.143512
# 3551                   xXx    998                0.120459
# 3550                   xXx   3714                0.448280
# 3548                   xXx    318                0.038383
# 3547                   xXx    272                0.032830
#
# [23048 rows x 3 columns]

# %% [markdown]
# #### EXERCISE
#
# What would be a good "gut check" to verify this operation?

# %% [markdown]
# #### Group By using the title, the sum of proportion_in_dialogue for each group should be one.

# %%
import pandas as pd

df_films_filter = df_films.groupby('title')['proportion_of_dialogue'].sum().reset_index()

df_films_filter.columns = ["title", "sum_proportion_of_dialogue"]

df_films_filter['sum_proportion_of_dialogue'] = df_films_filter['sum_proportion_of_dialogue'].round()
print(df_films_filter.head())
# Out:
#                         title  sum_proportion_of_dialogue
# 0        (500) Days of Summer                         1.0
# 1  10 Things I Hate About You                         1.0
# 2            12 Years a Slave                         1.0
# 3              12 and Holding                         1.0
# 4                   127 Hours                         1.0

# %%
filtered_df = df_films_filter[df_films_filter["sum_proportion_of_dialogue"] != 1]

print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [title, sum_proportion_of_dialogue]
# Index: []

# %% [markdown]
# ## Accessor Objects
#
# We've already seen many types of operations we can perform on virtually any kind of Series (or, DataFrame column), such as grouping, `transform`, adding/multiplying numbers, calculating aggregate values, etc. But, some operations which we have not discussed can only be applied to certain data types. For example, calculating a time interval makes sense given two dates, but it makes no sense given two random strings of characters.
#
# [pandas Accessors](https://pandas.pydata.org/pandas-docs/stable/reference/series.html?highlight=accessor#accessors) are datatype-specific methods which can be applied to particular Series defined in pandas. Each one provides a vast range of operationality with their corresponding kinds of data. In this notebook, we'll give a couple examples of the accessors for [Categories](https://pandas.pydata.org/docs/user_guide/categorical.html), [Strings](https://pandas.pydata.org/docs/user_guide/text.html), and [Datetimes](https://pandas.pydata.org/docs/user_guide/timeseries.html).

# %% [markdown]
# ### Category
#
# To illustrate some of the nice aspects of the `.cat` accessor, let's take a look at the *age* column.

# %%
df_films['age'].describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.99])
# Out:
# count    18263.000000
# mean        42.382960
# std         59.718859
# min          3.000000
# 10%         24.000000
# 25%         30.000000
# 50%         39.000000
# 75%         50.000000
# 99%         78.000000
# max       2013.000000
# Name: age, dtype: float64

# %% [markdown]
# Notice the maximum age ...

# %%
df_films[df_films['age'] > 100][['character', 'gender', 'age', 'title', 'release_year']]
# Out:
#              character gender     age                           title  \
# 4024     harold carnes      m  2000.0                 American Psycho
# 5254   margaret sulliv      f  2009.0                         Case 39
# 5370      bernie callo      m  2005.0                           Chaos
# 5950           realtor      m  2006.0                    The Departed
# 6899           thorpey      m  2000.0                      Get Carter
# 7787              bull      m  2007.0                   Into the Wild
# 7968   silent bob's mo      f  2001.0  Jay and Silent Bob Strike Back
# 9233       monty malik      m  1999.0               Never Been Kissed
# 9617            nessie      f  1993.0                       The Piano
# 9819          reporter      m  1980.0                     Raging Bull
# 10151    officer davis      m  1995.0                           Se7en
# 11639    lucas solomon      m  2013.0         The Wolf of Wall Street
# 13601       newscaster      m  1992.0                    Knight Moves
# 14385  himself       (      m   102.0                        Only You
# 14758  girl in bathroo      f  1996.0                          Scream
# 19222  captain ramirez      m  2007.0                      Borderland
# 21635      jack mccool      m  1996.0               Last Man Standing
#
#        release_year
# 4024           2000
# 5254           2009
# 5370           2005
# 5950           2006
# 6899           2000
# 7787           2007
# 7968           2001
# 9233           1999
# 9617           1993
# 9819           1980
# 10151          1995
# 11639          2013
# 13601          1992
# 14385          1994
# 14758          1996
# 19222          2007
# 21635          1996

# %% [markdown]
# Before we can even continue, we notice the age looks to be confused with the year of the movie release for several instances. There are a few ways to rectify this, but for now, we'll set incorrect age values to be missing. *What are some other ways we could manage this issue?*

# %%
# something a bit more explicit than an arbitrary "max" year
mask = df_films['age'] == df_films['release_year']

# %%
# pandas NaN is actually a np.nan object
df_films.loc[mask, 'age'] = np.nan

# %%
g = sns.histplot(df_films['age'], bins=20)
g.grid(False, axis='x');
# Out:
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Our goal here is to create categories based on the *age* of each character, i.e., we want "age groups". Since we should **never choose arbitrary breaks in data**, we'll use the [NIH age groups](https://www.nih.gov/nih-style-guide/age) to divide our data, and we'll translate the groups into our DataFrame using `cut`, as we've seen before.

# %%
df_films['age_group'] = pd.cut(df_films['age'], 
                               bins=[-1, 1, 12, 17, 65, 999],
                               labels=['Infant', 'Child', 'Adolescent', 'Adult', 'Older Adult'])

# %%
# data check
df_films.groupby('age_group')['age'].agg(['min', 'max'])
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_26192\3540895954.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_films.groupby('age_group')['age'].agg(['min', 'max'])
#               min    max
# age_group
# Infant        NaN    NaN
# Child         3.0   12.0
# Adolescent   13.0   17.0
# Adult        18.0   65.0
# Older Adult  66.0  102.0

# %%
df_films['age_group']
# Out:
# 0              Adult
# 1                NaN
# 2                NaN
# 3              Adult
# 4              Adult
#             ...
# 23043          Adult
# 23044    Older Adult
# 23045          Adult
# 23046    Older Adult
# 23047          Adult
# Name: age_group, Length: 23048, dtype: category
# Categories (5, object): ['Infant' < 'Child' < 'Adolescent' < 'Adult' < 'Older Adult']

# %%
df_films['age_group'].cat.ordered
# Out:
# True

# %% [markdown]
# Notice, categories can be *ordered* as the are here, and we can also use `cat.codes()` to convert them to numerical values (and back).

# %%
#  notice the use of `.cat` here
pd.concat((df_films['age_group'], 
           df_films['age_group'].cat.codes), axis=1).drop_duplicates()
# Out:
#        age_group  0
# 0          Adult  3
# 1            NaN -1
# 46    Adolescent  2
# 80   Older Adult  4
# 116        Child  1

# %%
df_films['age_group'].cat.categories
# Out:
# Index(['Infant', 'Child', 'Adolescent', 'Adult', 'Older Adult'], dtype='object')

# %% [markdown]
# Since the categories are ordered, we should see them show up "in order" in Seaborn plots, too. For example, suppose we are interested in looking at how the age group distribution in movies changes over the years.

# %%
df_films.head()
# Out:
#    script_id        character  words gender   age    imdb_id  \
# 0        280            betty    311      f  35.0  tt0112579
# 1        280  carolyn johnson    873      f   NaN  tt0112579
# 2        280          eleanor    138      f   NaN  tt0112579
# 3        280  francesca johns   2251      f  46.0  tt0112579
# 4        280            madge    190      f  46.0  tt0112579
#
#                            title  release_year  gross  proportion_of_dialogue  \
# 0  The Bridges of Madison County          1995  142.0                0.048639
# 1  The Bridges of Madison County          1995  142.0                0.136534
# 2  The Bridges of Madison County          1995  142.0                0.021583
# 3  The Bridges of Madison County          1995  142.0                0.352049
# 4  The Bridges of Madison County          1995  142.0                0.029715
#
#   age_group
# 0     Adult
# 1       NaN
# 2       NaN
# 3     Adult
# 4     Adult

# %%
df_films_by_year = df_films.groupby(['release_year', 'age_group'], observed=True)['character'].agg([('num_characters', 'count')]).reset_index()
df_films_by_year.head()
# Out:
#    release_year    age_group  num_characters
# 0          1929        Adult               6
# 1          1931        Adult              11
# 2          1931  Older Adult               1
# 3          1932        Adult              43
# 4          1932  Older Adult               4

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(9, 6))

# adults included
sns.lineplot(df_films_by_year, x='release_year', y='num_characters', hue='age_group', ax=axes[0])
axes[0].grid(False, axis='x')
axes[0].set_title("Adults Included")

# adults excluded
mask = df_films_by_year['age_group'] != 'Adult'
sns.lineplot(df_films_by_year[mask], x='release_year', y='num_characters', hue='age_group', ax=axes[1])
axes[1].grid(False, axis='x')
axes[1].set_title("Without Adults");
# Out:
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\varsh\miniconda3\envs\env1\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %% [markdown]
# ### EXERCISE
#
# What are some issues with these plots? Try to come up with at least one issue with the above data visualizations, and edit (or, rewrite) the code to build a different view of the data.

# %% [markdown]
# #### Line plots, in my opinion, may not effectively display data because they are frequently used to visualize relationships between two continuous variables. A bar graph or box plot might be a better choice of graphical representation.

# %%
import pandas as pd

# Define a function to bin release years into decades
def assign_decade(year):
    return year // 10 * 10

# Apply the function to create the 'release_decade' column
df_films_by_year['release_decade'] = df_films_by_year['release_year'].apply(assign_decade)

# Group by 'release_decade' and 'age_group', and aggregate 'num_characters'
df_films_by_decade = df_films_by_year.groupby(['release_decade', 'age_group']).agg({'num_characters': 'sum'}).reset_index()
# Out:
# C:\Users\varsh\AppData\Local\Temp\ipykernel_26192\3964263077.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_films_by_decade = df_films_by_year.groupby(['release_decade', 'age_group']).agg({'num_characters': 'sum'}).reset_index()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))

for age_group in df_films_by_decade['age_group'].unique():
    data = df_films_by_decade[df_films_by_decade['age_group'] == age_group]

    ax.bar(data['release_decade'], data['num_characters'], label=age_group)

ax.set_title("Number of Characters Over Release Decades by Age Group")
ax.set_xlabel("Release Decade")
ax.set_ylabel("Number of Characters")

ax.legend(title='Age Group', loc='upper left')
ax.grid(axis='y')

plt.show()

# %% [markdown]
# ### String
#
# pandas also provides accessors objects for strings. Built from the Python string methods, the pandas string methods will transform each string value in a column, and run the operator called after `.str`.

# %% [markdown]
# | **Pandas String Method** | **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | df['column_name']`.str.lower()`         | makes the string in each row lowercase                                                                                |
# | df['column_name']`.str.upper()`         | makes the string in each row uppercase                                                |
# | df['column_name']`.str.title()`         | makes the string in each row titlecase                                                |
# | df['column_name']`.str.replace('old string', 'new string')`      | replaces `old string` with `new string` for each row |
# | df['column_name']`.str.contains('some string')`      | tests whether string in each row contains "some string" |
# | df['column_name']`.str.split('delim')`          | returns a list of substrings separated by the given delimiter |
# | df['column_name']`.str.join(list)`         | opposite of split(), joins the elements in the given list together using the string                                                                        |

# %% [markdown]
# For example, to transform every character's name in the "character" column from all lowercase to title case (i.e., capitalize the first letter of each "word"), we can use `.str.title()` .

# %%
df_films['character'] = df_films['character'].str.title()
df_films['character'].head()
# Out:
# 0              Betty
# 1    Carolyn Johnson
# 2            Eleanor
# 3    Francesca Johns
# 4              Madge
# Name: character, dtype: object

# %% [markdown]
# If we want to replace the gender column's single letter abbreviation to "male" / "female", we could use the `.str.replace()` method.

# %%
df_films['gender'] = df_films['gender'].str.replace('m', 'male')

# %%
df_films['gender'] = df_films['gender'].str.replace('f', 'female')

# %%
df_films.sample(5)
# Out:
#        script_id      character  words  gender   age    imdb_id  \
# 7164        2460          Susan    860  female  29.0  tt0391198
# 16355       5481      Mr. Trout    306    male  42.0  tt0787474
# 10036       3244     Niki Lauda   2891    male  35.0  tt1979320
# 6105        2177  Karen Pomeroy    568  female  26.0  tt0246578
# 2702        1286        Sampson    148    male   NaN  tt1645131
#
#                 title  release_year  gross  proportion_of_dialogue age_group
# 7164       The Grudge          2004  154.0                0.134165     Adult
# 16355   The Boxtrolls          2014   54.0                0.058497     Adult
# 10036            Rush          2013   28.0                0.308308     Adult
# 6105     Donnie Darko          2001    1.0                0.082811     Adult
# 2702   Romeo & Juliet          2013    1.0                0.022720       NaN

# %% [markdown]
# We can use the `.str.contains()` to search for particular words or phrases in a column, such as "Star Wars."

# %%
df_films[df_films['title'].str.contains('Star Wars')].sample(5)
# Out:
#        script_id        character  words  gender   age    imdb_id  \
# 3017        1359   Admiral Ackbar    199    male  61.0  tt0086190
# 10600       3427            Padme   1561  female  24.0  tt0121766
# 10593       3427  Clone Jedi Knig    104    male   NaN  tt0121766
# 21005       8099         Kylo Ren    618    male  32.0  tt2488496
# 10615       3433    Snow Creature    227    male   NaN  tt0080684
#
#                                                 title  release_year  gross  \
# 3017       Star Wars: Episode VI - Return of the Jedi          1983  853.0
# 10600    Star Wars: Episode III - Revenge of the Sith          2005  515.0
# 10593    Star Wars: Episode III - Revenge of the Sith          2005  515.0
# 21005      Star Wars: Episode VII - The Force Awakens          2015  927.0
# 10615  Star Wars: Episode V - The Empire Strikes Back          1980  937.0
#
#        proportion_of_dialogue age_group
# 3017                 0.039096     Adult
# 10600                0.112326     Adult
# 10593                0.007484       NaN
# 21005                0.092709     Adult
# 10615                0.024586       NaN

# %% [markdown]
# ### Datetime
#
# The pandas `datetime` object contains several different [methods](https://pandas.pydata.org/pandas-docs/stable/reference/series.html?highlight=accessor#datetimelike-properties) which can be used to shed light on date/datetime data, but the benefit of using them is most apparent when we have dates/times down to the day or even hour. In `df_films`, we only have year aggregation, so it would be difficult to show the benefits of the datetime accessor.
#
# We will discuss datetime Series in-depth when we cover Time Series data in a later lesson, but for now we'll introduce them using a related data set found on [Box Office Mojo](https://www.boxofficemojo.com), namely the 2023 [top 200 box office films](https://www.boxofficemojo.com/year/2023).
#
# **A Quick Note on Web Scraping**
#
# Web scraping is a method by which we collect data from websites online using code. There are several Python packages built specifically for web scraping (e.g., [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/), and [Scrapy](https://scrapy.org/)), but this method of collecting data is usually less effective than other alternatives we'll discuss in future lessons. That said, when web scraping actually is more effective, usually the website uses HTML tables, which pandas can parse using `read_html`.
#
# *Note: you may need to install `lxml` (in this environment; and restart your kernel) to run the next cell.*

# %%
# see the documentation on `read_html`
df_mojo = pd.read_html('https://www.boxofficemojo.com/year/2023', match='Rank')[0]
df_mojo.head()
# Out:
#    Rank                              Release Genre Budget Running Time  \
# 0     1                               Barbie     -      -            -
# 1     2          The Super Mario Bros. Movie     -      -            -
# 2     3  Spider-Man: Across the Spider-Verse     -      -            -
# 3     4       Guardians of the Galaxy Vol. 3     -      -            -
# 4     5                          Oppenheimer     -      -            -
#
#           Gross Theaters   Total Gross Release Date  \
# 0  $636,225,983     4337  $636,238,421       Jul 21
# 1  $574,934,330     4371  $574,934,330        Apr 5
# 2  $381,311,319     4332  $381,311,319        Jun 2
# 3  $358,995,815     4450  $358,995,815        May 5
# 4  $326,101,370     3761  $329,153,395       Jul 21
#
#                            Distributor  Estimated
# 0                         Warner Bros.      False
# 1                   Universal Pictures      False
# 2                    Columbia Pictures      False
# 3  Walt Disney Studios Motion Pictures      False
# 4                   Universal Pictures      False

# %%
# these are some columns we don't need
df_mojo.drop(columns=['Genre', 'Budget', 'Running Time', 'Estimated'], inplace=True)

# %%
# clean up column names using a dictionary comprehension
df_mojo.rename(columns={c:c.lower().replace(" ", "_") for c in df_mojo.columns},
               inplace=True)

# %%
df_mojo.columns
# Out:
# Index(['rank', 'release', 'gross', 'theaters', 'total_gross', 'release_date',
#        'distributor'],
#       dtype='object')

# %%
df_mojo['release_date']
# Out:
# 0      Jul 21
# 1       Apr 5
# 2       Jun 2
# 3       May 5
# 4      Jul 21
#         ...
# 195    May 12
# 196    Dec 23
# 197     Apr 7
# 198    Mar 17
# 199     Jun 2
# Name: release_date, Length: 200, dtype: object

# %% [markdown]
# It's a bit rare to see a date column without a year. Since we know the year for all of these is 2023 (this comes from the 2023 box office), we can tack that on to the release date using the `+` operator. Then, `pd.to_datetime` is the [preferred method](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) to parse and convert a date-looking string into a datetime object.

# %%
df_mojo['release_date'] = pd.to_datetime(df_mojo['release_date'] + " 2023")

# %%
df_mojo['release_date']
# Out:
# 0     2023-07-21
# 1     2023-04-05
# 2     2023-06-02
# 3     2023-05-05
# 4     2023-07-21
#          ...
# 195   2023-05-12
# 196   2023-12-23
# 197   2023-04-07
# 198   2023-03-17
# 199   2023-06-02
# Name: release_date, Length: 200, dtype: datetime64[ns]

# %% [markdown]
# Let's make a column for the month of the release, and another one for the quarter.

# %%
df_mojo['release_month'] = df_mojo['release_date'].dt.month
df_mojo['release_quarter'] = df_mojo['release_date'].dt.quarter

# %% [markdown]
# ## Applying Functions
#
# ### Lambda Functions
#
# Before we go on, let's take a quick aside from pandas to introduce [anonymous functions](https://realpython.com/python-lambda/#anonymous-functions), or in Python "lambda functions". As we've seen before, we can define "named" functions `myfunc` in Python using the standard `def` and `return` syntax, and then call them with parentheses `myfunc()`. But, it's not always the case that you need a function that can be called, rather you want to use the power of a function within another method. For this, we use a lambda function, which is set to take in some set of variables, and return a result.
#
#     lambda var1: f(var1)
#     lambda var1, var2: f(var1, var2)
#
# For example, suppose we are given a list of full names, and we want to sort them based on the last name.

# %%
names = ["Jean-Luc Picard", "Beverly Crusher", "Deanna Troi", "William Riker", "Geordi LaForge"]
sorted(names)
# Out:
# ['Beverly Crusher',
#  'Deanna Troi',
#  'Geordi LaForge',
#  'Jean-Luc Picard',
#  'William Riker']

# %%
sorted(names, key=lambda n: n.split(" ")[1])
# Out:
# ['Beverly Crusher',
#  'Geordi LaForge',
#  'Jean-Luc Picard',
#  'William Riker',
#  'Deanna Troi']

# %% [markdown]
# ### Map, Filter, and Reduce
#
# Another use for lambda functions (outside of pandas, that is) involves using `map`, `filter`, or `reduce` functions.

# %%
from functools import reduce

# %% [markdown]
# The `map` function "applies" a given function to each element of an iterable. It returns a [*generator*](https://realpython.com/introduction-to-python-generators/#understanding-generators) object, which as we've seen before needs to be iterated through. **Think of a generator like a slide deck**, where the thing itself doesn't reveal any of its elements until you are ready for the "next slide". Also like a slide deck, when it's over, it's over.

# %%
first_names = map(lambda n: n.split(" ")[0], names)

# %%
# run this cell until you can't anymore ...
next(first_names)
# Out:
# 'Jean-Luc'

# %%
# after running the above cell, we need to redefine the generator
first_names = map(lambda n: n.split(" ")[0], names)
[i for i in first_names]
# Out:
# ['Jean-Luc', 'Beverly', 'Deanna', 'William', 'Geordi']

# %%
# after running the above cell, try running this cell
# [i for i in first_names]

# %% [markdown]
# `filter` is similar to `map` in that it returns a generator, but its purpose is to *filter* the elements of the iterable based on some condition.

# %%
hyphenated_names = filter(lambda n: "-" in n, names)
[i for i in hyphenated_names]
# Out:
# ['Jean-Luc Picard']

# %% [markdown]
# Lastly, `reduce` is meant to combine elements into one. It uses a function which (typically) takes in two variables. This function is applied to the first two elements of the iterable, and then its applied to the resulting value and the next element of the iterable, and so on.
#
#     reduce(lambda a, b: f(a, b), [e1, e2, e3, e4, e5])
#
#     step 1: f(e1, e2) ---> R1
#     step 2: f(R1, e3) ---> R2
#     step 3: f(R2, e4) ---> R3
#     step 4: f(R3, e5) ---> final result
#
# For example, we can use it to compute an average of a set of numbers.

# %%
list_of_numbers = [5, 4, 2, 7, 19]

# %%
reduce(lambda a, b: a + b, list_of_numbers) / len(list_of_numbers)
# Out:
# 7.4

# %%
np.mean(list_of_numbers)
# Out:
# 7.4

# %% [markdown]
# Or, further, an average of averages, if we combine `map` with `reduce`.

# %%
list_of_samples = [[1, 4, 3], [5, 4, 2], [9, 2, 1]]

# %%
list_of_averages = map(np.mean, list_of_samples)

# %%
# sum of three values over 3
reduce(lambda a, b: a + b, list_of_averages) / len(list_of_samples)
# Out:
# 3.444444444444444

# %%
# this list comprehension will flatten a list of lists
l = [e for sublist in list_of_samples for e in sublist]
l
# Out:
# [1, 4, 3, 5, 4, 2, 9, 2, 1]

# %%
# the average of averages is the average of the full set
np.mean(l)
# Out:
# 3.4444444444444446

# %% [markdown]
# Note, ["Map-Reduce"](https://en.wikipedia.org/wiki/MapReduce) is actually a process by which (a cluster of) computers can manage processing on huge (petabyte-scale) datasets, and it uses an application of exactly the same idea above, just on a much larger scale.

# %% [markdown]
# ### Apply Functions
#
# Using the same sort of thinking we've illustrated above, we can *apply* functions (lambda or otherwise) across all values in a column (or, any number of columns) using `.apply`. For instance, in `df_films`, we notice that character names are sometimes single names (like "Peter"), and other times, they contain last names or sometimes even middle names. Let's make a column that counts the number of "sub-names" in a characters name.

# %%
df_films[df_films['character'].isna()]
# Out:
#        script_id character  words  gender  age    imdb_id           title  \
# 4656        1807       NaN    146  female  NaN  tt0120603         Beloved
# 19448       7445       NaN    520  female  NaN  tt0093223  House of Games
#
#        release_year  gross  proportion_of_dialogue age_group
# 4656           1998   42.0                0.005162       NaN
# 19448          1987    5.0                0.165184       NaN

# %%
def subnames(name):
    '''
    Using the idea that multiple subnames can only occur with a space, we 
    count the spaces, and add one to get the number of subnames.
    '''
    # what if the character name is missing?
    if pd.isna(name):
        n_subnames = 0
    else:
        n_subnames = name.count(" ") + 1
        
    return n_subnames

# %%
df_films['n_character_subnames'] = df_films['character'].apply(subnames)

# %%
df_films['n_character_subnames'].unique()
# Out:
# array([1, 2, 3, 4, 7, 5, 8, 0, 6, 9], dtype=int64)

# %% [markdown]
# Greater than four subnames seems a bit odd. To investigate this particular number of subnames (as a start), we can also use `.apply` on the column axis. In this way, the function is taking in a row (i.e., a pandas Series).

# %%
def messy_name(r):
    # this number 
    if r['n_character_subnames'] > 4:
        subnames = r['character'].split(" ")
    else:
        subnames = "not messy"
    return subnames

# %%
df_films['messy_name'] = df_films.apply(messy_name, axis=1)

# %%
cols = ['character', 'n_character_subnames', 'messy_name']
df_films[df_films['messy_name'] != "not messy"][cols]
# Out:
#              character  n_character_subnames                 messy_name
# 1449   Mr. Borgin                          7    [Mr., Borgin, , , , , ]
# 2623   Riff Raff - A H                     5      [Riff, Raff, -, A, H]
# 2959   Gregory       (                     8   [Gregory, , , , , , , (]
# 4723   Sam - Man In Di                     5      [Sam, -, Man, In, Di]
# 5026   Ward Abbott                         6     [Ward, Abbott, , , , ]
# 6088   Clinic Girl                         6     [Clinic, Girl, , , , ]
# 7077   Clerk        (U                     9  [Clerk, , , , , , , , (U]
# 7303   Watts       (Ar                     8   [Watts, , , , , , , (Ar]
# 8089   Fidget       (C                     8   [Fidget, , , , , , , (C]
# 8833   Bert       (Cre                     8   [Bert, , , , , , , (Cre]
# 9250   Smokey       (A                     8   [Smokey, , , , , , , (A]
# 9349   Duane Cooley                        5      [Duane, Cooley, , , ]
# 11549  Beany Thorn                         6     [Beany, Thorn, , , , ]
# 11553  Chet       (Sce                     8   [Chet, , , , , , , (Sce]
# 11564  Red       (Scen                     8   [Red, , , , , , , (Scen]
# 13818  A Man On A Dais                     5      [A, Man, On, A, Dais]
# 13937  The Magician                        5      [The, Magician, , , ]
# 14385  Himself       (                     8   [Himself, , , , , , , (]
# 15446  Lucy Moran                          7    [Lucy, Moran, , , , , ]
# 16908  Chad Kaplan                         6     [Chad, Kaplan, , , , ]
# 20421  Clubber Lang                        5      [Clubber, Lang, , , ]

# %% [markdown]
# ## Melt and Pivot
#
# When we extract data from [The World Bank Databases](https://data.worldbank.org/), we need to be careful to set the layout so that our data is in the orientation we want. In most cases, we want a "long" data frame where columns are variables, rows are observations, and values correspond to the two. Let's take a look at a small set of data extracted from the [Food Prices for Nutrition](https://databank.worldbank.org/source/food-prices-for-nutrition) database, where the orientation isn't quite right.

# %%
df_foods = pd.read_csv("./data/cost_of_food.csv").dropna()
df_foods.head()
# Out:
#              Classification Name Classification Code   Country Name  \
# 0  Food Prices for Nutrition 1.0             FPN 1.0  United States
# 1  Food Prices for Nutrition 1.0             FPN 1.0  United States
# 2  Food Prices for Nutrition 1.0             FPN 1.0  United States
# 3  Food Prices for Nutrition 1.0             FPN 1.0          World
# 4  Food Prices for Nutrition 1.0             FPN 1.0          World
#
#   Country Code                                        Series Name  \
# 0          USA                             Cost of a healthy diet
# 1          USA                                         Population
# 2          USA  Millions of people who cannot afford a healthy...
# 3          WLD                             Cost of a healthy diet
# 4          WLD                                         Population
#
#        Series Code  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 0             CoHD   3.225000e+00   3.240000e+00   3.268000e+00
# 1              Pop   3.251221e+08   3.268382e+08   3.283300e+08
# 2  CoHD_unafford_n   6.500000e+00   5.700000e+00   4.900000e+00
# 3             CoHD   3.314000e+00   3.350000e+00   3.425000e+00
# 4              Pop   7.208181e+09   7.249963e+09   7.327597e+09
#
#    2020 [YR2020] 2021 [YR2021]
# 0   3.383000e+00            ..
# 1   3.294841e+08            ..
# 2   4.900000e+00            ..
# 3   3.537000e+00            ..
# 4   7.401935e+09            ..

# %%
# clean up columns names
def clean_col_name(col):
    if 'YR' in col:
        end = col.find('[') - 1
        return col[:end]
    else:
        return col.lower().replace(" ", "_")
        
df_foods.rename(columns={c: clean_col_name(c) for c in df_foods.columns},
                inplace=True)

# %%
# we want country, series, and year for Food Prices for Nutrition (FPN) 2.0
df_foods = df_foods[df_foods['classification_code'] == "FPN 2.0"] \
                .drop(columns=['classification_name', 
                               'classification_code',
                               'country_code', 'series_code'])

# %%
df_foods
# Out:
#      country_name                                        series_name  \
# 12  United States                             Cost of a healthy diet
# 13  United States                                         Population
# 14  United States  Millions of people who cannot afford a healthy...
# 15          World                             Cost of a healthy diet
# 16          World                                         Population
# 17          World  Millions of people who cannot afford a healthy...
#
#             2017          2018          2019          2020        2021
# 12  3.225000e+00  3.240000e+00  3.268000e+00  3.383000e+00         3.5
# 13  3.251221e+08  3.268382e+08  3.283300e+08  3.315011e+08   331893745
# 14  6.500000e+00  5.700000e+00  4.900000e+00  4.100000e+00           4
# 15  3.295000e+00  3.355000e+00  3.431000e+00  3.511000e+00       3.662
# 16  7.262444e+09  7.304447e+09  7.381667e+09  7.455672e+09  7519145737
# 17  3.124900e+03  3.019100e+03  3.005500e+03  3.191900e+03      3139.5

# %% [markdown]
# ### Melt
#
# Notice that the *series_name* column actually contains what we want to be *column* names. Also, note that each year listed here should really be a *row* value. This data frame is an example of a "wide" data frame, which we want to be reoriented as a "long" data frame. To do this, we use `melt` to create another data frame which is still technically wide, but at least brings us closer to what we want. Here, the columns that we are "melting" are the years.

# %%
df_foods_melted = df_foods.melt(id_vars=['country_name', 'series_name'],
                                value_vars=[c for c in df_foods if 'name' not in c],  # <-- melt
                                value_name="series_value",
                                var_name='year')

# %%
df_foods_melted
# Out:
#      country_name                                        series_name  year  \
# 0   United States                             Cost of a healthy diet  2017
# 1   United States                                         Population  2017
# 2   United States  Millions of people who cannot afford a healthy...  2017
# 3           World                             Cost of a healthy diet  2017
# 4           World                                         Population  2017
# 5           World  Millions of people who cannot afford a healthy...  2017
# 6   United States                             Cost of a healthy diet  2018
# 7   United States                                         Population  2018
# 8   United States  Millions of people who cannot afford a healthy...  2018
# 9           World                             Cost of a healthy diet  2018
# 10          World                                         Population  2018
# 11          World  Millions of people who cannot afford a healthy...  2018
# 12  United States                             Cost of a healthy diet  2019
# 13  United States                                         Population  2019
# 14  United States  Millions of people who cannot afford a healthy...  2019
# 15          World                             Cost of a healthy diet  2019
# 16          World                                         Population  2019
# 17          World  Millions of people who cannot afford a healthy...  2019
# 18  United States                             Cost of a healthy diet  2020
# 19  United States                                         Population  2020
# 20  United States  Millions of people who cannot afford a healthy...  2020
# 21          World                             Cost of a healthy diet  2020
# 22          World                                         Population  2020
# 23          World  Millions of people who cannot afford a healthy...  2020
# 24  United States                             Cost of a healthy diet  2021
# 25  United States                                         Population  2021
# 26  United States  Millions of people who cannot afford a healthy...  2021
# 27          World                             Cost of a healthy diet  2021
# 28          World                                         Population  2021
# 29          World  Millions of people who cannot afford a healthy...  2021
#
#     series_value
# 0          3.225
# 1    325122128.0
# 2            6.5
# 3          3.295
# 4   7262444211.0
# 5         3124.9
# 6           3.24
# 7    326838199.0
# 8            5.7
# 9          3.355
# 10  7304446818.0
# 11        3019.1
# 12         3.268
# 13   328329953.0
# 14           4.9
# 15         3.431
# 16  7381666960.0
# 17        3005.5
# 18         3.383
# 19   331501080.0
# 20           4.1
# 21         3.511
# 22  7455671559.0
# 23        3191.9
# 24           3.5
# 25     331893745
# 26             4
# 27         3.662
# 28    7519145737
# 29        3139.5

# %% [markdown]
# ### Pivot
#
# Now, we will create a proper "long" data frame by **pivoting** the *series_name* column as columns. We do this using `pd.pivot`. This is sort of the *reverse* of `melt`.

# %%
df_foods_pivoted = pd.pivot(df_foods_melted, 
                            index=['country_name', 'year'],   # a unique identifier for each row
                            columns=['series_name'],          # the column containing column names
                            values='series_value')            # the values of interest

df_foods_pivoted.reset_index(inplace=True) 
df_foods_pivoted.rename_axis(None, axis=1, inplace=True)      # remove the named index

# %%
df_foods_melted.sample(5)
# Out:
#      country_name                                        series_name  year  \
# 14  United States  Millions of people who cannot afford a healthy...  2019
# 15          World                             Cost of a healthy diet  2019
# 24  United States                             Cost of a healthy diet  2021
# 2   United States  Millions of people who cannot afford a healthy...  2017
# 20  United States  Millions of people who cannot afford a healthy...  2020
#
#    series_value
# 14          4.9
# 15        3.431
# 24          3.5
# 2           6.5
# 20          4.1

# %%
df_foods_pivoted.sample(5)
# Out:
#     country_name  year Cost of a healthy diet  \
# 6          World  2018                  3.355
# 7          World  2019                  3.431
# 1  United States  2018                   3.24
# 8          World  2020                  3.511
# 9          World  2021                  3.662
#
#   Millions of people who cannot afford a healthy diet    Population
# 6                                             3019.1   7304446818.0
# 7                                             3005.5   7381666960.0
# 1                                                5.7    326838199.0
# 8                                             3191.9   7455671559.0
# 9                                             3139.5     7519145737

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# ## Part 1
#
# Each one of these movies is a top box office movie, which we can temporarily call a "blockbuster". Let's investigate the (financial) performance of these movies based on how long it's been since the last blockbuster was released. (So, we're looking at the time between each row as the "time since last blockbuster"...)
#
# In this exercise, make a new column which represents the time since the last blockbuster, and plot the *total_gross* (as a number) against that value.
#
# *Hint: Take a look at the pandas [`shift`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html) method.*

# %%
df_films['release_year'] = pd.to_datetime(df_films['release_year'], format='%Y')

df_films['time_since_last_blockbuster'] = df_films['release_year'].shift()

plt.plot(df_films['time_since_last_blockbuster'], df_films['gross'], 'bo')
plt.title('Total Gross vs Time Since Last Blockbuster')
plt.xlabel('Time Since Last Blockbuster (Days)')
plt.ylabel('Total Gross')
plt.show()

# %% [markdown]
# ## Part 2
#
# Clean up the *character* column of `df_films`. We want to do our best to make sure that every value in this column is assigned to a meaningful character name.

# %% [markdown]
# Before Cleaning, the number of rows in df_films is 23048

# %%
df_films.shape
# Out:
# (23048, 14)

# %%
df_films.dropna(subset=['character'], inplace=True)

def clean_character_name(name):
    valid_pattern = r'^[a-zA-Z\s.\']+$'

    if re.match(valid_pattern, name):
        return name
    else:
        match = re.search(r'\b[A-Za-z]+(?=\s*\d+\b)', name)
        if match:
            return match.group()
        else:
            print("The character name removed is: "+name)
            return None
            
df_films['character'] = df_films['character'].apply(clean_character_name)

df_films.dropna(subset=['character'], inplace=True)
# Out:
# The character name removed is: Alex, The Pimp
# The character name removed is: F-15 Leader Col
# The character name removed is: Reporter #1
# The character name removed is: Voice Of Rok, T
# The character name removed is: Count Orsini-Ro
# The character name removed is: 2-Star General
# The character name removed is: Carl Mickens -
# The character name removed is: Zuria - Journal
# The character name removed is: Mau Mau: Big Bl
# The character name removed is: �Tienne
# The character name removed is: Fran�Oise
# The character name removed is: Butt-Head
# The character name removed is: Dr. Bennett - S
# The character name removed is: Ed Bloom - Youn
# The character name removed is: Jenny - Young
# The character name removed is: Sandra Bloom -
# The character name removed is: Longshanks - Ki
# The character name removed is: Chairman, Joint
# The character name removed is: Gangooly - Con
# The character name removed is: Corridor - John
# The character name removed is: Jean-Claude
# The character name removed is: Kob-Tv Reporter
# The character name removed is: 747 Captain
# The character name removed is: Jean-Baptiste E
# The character name removed is: Local Anchor #1
# The character name removed is: Man #2
# The character name removed is: Dr. Ren� Belloq
# The character name removed is: Waiter #1
# The character name removed is: Dalai Lama (Adu
# The character name removed is: Layman #1
# The character name removed is: Rambler-Crane S
# The character name removed is: Brad 'B-Rad' Gl
# The character name removed is: Sheila - Jesse'
# The character name removed is: Mr. Peters - Ne
# The character name removed is: Tony - Downstai
# The character name removed is: Eileen, Waitres
# The character name removed is: Lottie, Mack'S
# The character name removed is: Mack, The Farme
# The character name removed is: Wendy-The Revol
# The character name removed is: B) Shane
# The character name removed is: Brad Majors - A
# The character name removed is: Columbia - A Gr
# The character name removed is: Dr. Frank-N-Fur
# The character name removed is: Janet Weiss - A
# The character name removed is: Magenta - A Dom
# The character name removed is: Riff Raff - A H
# The character name removed is: Jean-Pierre
# The character name removed is: Pooh-Bear
# The character name removed is: J�Ns, Squire
# The character name removed is: Karin, Block'S
# The character name removed is: Lisa, Blacksmit
# The character name removed is: Eugene Sutphin,
# The character name removed is: Bullet-Tooth To
# The character name removed is: Gregory       (
# The character name removed is: Vinny - Crunche
# The character name removed is: Ben 'Obi-Wan' K
# The character name removed is: C-3Po
# The character name removed is: Obi-Wan Kenobi
# The character name removed is: Ben Obi-Wan Ken
# The character name removed is: C-3Po
# The character name removed is: Cmdr. Praji (Im
# The character name removed is: Red Three (Bigg
# The character name removed is: Uberto Pazzi-Sf
# The character name removed is: Charlene - Aka
# The character name removed is: Floyd - Bodygua
# The character name removed is: Cap - Bartender
# The character name removed is: Stan - Depot Ma
# The character name removed is: Alpa Chino - Ho
# The character name removed is: Cody - Vietnam
# The character name removed is: Jeff Portnoy -
# The character name removed is: Rick Peck - Pec
# The character name removed is: Tran - Flaming
# The character name removed is: Tugg Speedman -
# The character name removed is: Tv Reporter, Os
# The character name removed is: Novello, Nightc
# The character name removed is: Frizzy, Hotel D
# The character name removed is: Lisa, Blonde Ho
# The character name removed is: Autumn - Girl A
# The character name removed is: Eug�Ne Lyon
# The character name removed is: Doc Mimms, Zee'
# The character name removed is: Thaddeus Rains,
# The character name removed is: Sarah, The Soph
# The character name removed is: President Ren�
# The character name removed is: Larry Pogue, Sr
# The character name removed is: Handmaiden #1
# The character name removed is: Jerry, Civilian
# The character name removed is: Mp Sergeant #1
# The character name removed is: Julie C�Te
# The character name removed is: Co-Pilot Jennif
# The character name removed is: Jennifer, Elect
# The character name removed is: Autumn Woman #1
# The character name removed is: Trudy Chac�N
# The character name removed is: Doctor - Vet
# The character name removed is: John - Border P
# The character name removed is: Reporter - Us N
# The character name removed is: Ricco, Patholog
# The character name removed is: Willy, Bartende
# The character name removed is: Murphy - Captai
# The character name removed is: Chase Rubin-Ros
# The character name removed is: Melody (Garrett
# The character name removed is: Two-Face
# The character name removed is: Deke Carter - D
# The character name removed is: Mrs. Bundy - Or
# The character name removed is: Sam - Man In Di
# The character name removed is: Sophia, Alias N
# The character name removed is: Milford #66
# The character name removed is: Jeweller #1
# The character name removed is: Judge (Chicago)
# The character name removed is: Cop #1
# The character name removed is: 500 Race Announ
# The character name removed is: Date-Rape Woman
# The character name removed is: �Lex
# The character name removed is: Judit Garc�A
# The character name removed is: 911 Operator
# The character name removed is: Amy Rothstein (
# The character name removed is: Joan Ostrowski-
# The character name removed is: 911 Operator
# The character name removed is: Stan Michaels,
# The character name removed is: Tom Sisler, Pri
# The character name removed is: Maria Di Vita -
# The character name removed is: Salvatore 'Tot�
# The character name removed is: Angry Hockey-Pl
# The character name removed is: Traffic Cop #1
# The character name removed is: Stickman #1
# The character name removed is: First Citizen (
# The character name removed is: Hood #3
# The character name removed is: T-Bird
# The character name removed is: Commentator (We
# The character name removed is: James Gordon, J
# The character name removed is: Watkins - Missi
# The character name removed is: David Peretz (T
# The character name removed is: Dieter Vogel (B
# The character name removed is: Rachel Singer (
# The character name removed is: Sarah Gold (Tel
# The character name removed is: Stephan Gold (T
# The character name removed is: Detective #1 Ta
# The character name removed is: Beefy Jerk #1
# The character name removed is: Garson Deeds -
# The character name removed is: Judge Sklar - M
# The character name removed is: Mitch Weaver -
# The character name removed is: Newscaster (Wzd
# The character name removed is: Pilot (Northeas
# The character name removed is: Stewardess - No
# The character name removed is: Connie Rudr�D,
# The character name removed is: Harold Vilmes,
# The character name removed is: Terry Macy, Sta
# The character name removed is: Director-2Nd Te
# The character name removed is: Michelle - Clas
# The character name removed is: Fenelon-Barnes
# The character name removed is: Peters, Med Tec
# The character name removed is: Hooker #1
# The character name removed is: Young Girl (Ali
# The character name removed is: Reporter #7
# The character name removed is: Angela (Segment
# The character name removed is: Athena (Segment
# The character name removed is: Chester (Segmen
# The character name removed is: Elspeth (Segmen
# The character name removed is: Eva (Segment "T
# The character name removed is: Jezebel (Segmen
# The character name removed is: Juancho (Segmen
# The character name removed is: Kiva (Segment "
# The character name removed is: Leo (Segment "T
# The character name removed is: Norman (Segment
# The character name removed is: Raven (Segment
# The character name removed is: Sarah (Segment
# The character name removed is: Sigfried (Segme
# The character name removed is: Wife (Segment "
# The character name removed is: Reports, Public
# The character name removed is: Gordy Jr. (10 Y
# The character name removed is: Newscaster #1
# The character name removed is: Pete Bottoms, L
# The character name removed is: Velma - Ticket
# The character name removed is: Comedy & Magic
# The character name removed is: George, Georgie
# The character name removed is: Herself (Direct
# The character name removed is: Jimmy Capp (Ray
# The character name removed is: Gerrold, The Pu
# The character name removed is: Jerome, The Ang
# The character name removed is: Margaret - Art
# The character name removed is: Executive #1
# The character name removed is: Henry Lipkin -
# The character name removed is: Clerk        (U
# The character name removed is: Flaemmchen - Th
# The character name removed is: Grusinskaya - T
# The character name removed is: Senf - The Port
# The character name removed is: Larry Oster-Ber
# The character name removed is: Jule - Bouncer
# The character name removed is: Hog-Head
# The character name removed is: Wormtail (Peter
# The character name removed is: Watts       (Ar
# The character name removed is: Twin #1
# The character name removed is: Tommy Five-Tone
# The character name removed is: Kamarov - Red O
# The character name removed is: Lt. Melekhin -
# The character name removed is: Navigator C-2A
# The character name removed is: Russian Cob - R
# The character name removed is: Amy - Billingsl
# The character name removed is: Johnson (Soldie
# The character name removed is: Cop #1
# The character name removed is: Teen #1
# The character name removed is: Fbi Agent - Fra
# The character name removed is: Himself - Walki
# The character name removed is: Himself - With
# The character name removed is: Tv Newsman #1
# The character name removed is: Su-Chin
# The character name removed is: Fidget       (C
# The character name removed is: Girl #1
# The character name removed is: Samuel - Male N
# The character name removed is: Check-In Stewar
# The character name removed is: Tom - Un Cin�As
# The character name removed is: �Ponine
# The character name removed is: Drug Dealer #1
# The character name removed is: Hong, Chinese R
# The character name removed is: Nurse #1
# The character name removed is: Pi Patel (11-12
# The character name removed is: Ravi Patel (7 Y
# The character name removed is: Angel #1
# The character name removed is: Patrolman #1
# The character name removed is: Paige #1
# The character name removed is: Chad, Seduce &
# The character name removed is: Janet, Frank'S
# The character name removed is: Maynard Smith -
# The character name removed is: Neighbor Mom (N
# The character name removed is: 1St Lt. Tom Pul
# The character name removed is: 2Nd Lt. William
# The character name removed is: Awkward Davies,
# The character name removed is: Blakeney, Midsh
# The character name removed is: Calamy, Midship
# The character name removed is: Capt. Howard, R
# The character name removed is: Hollom, Midship
# The character name removed is: Joe Plaice, Abl
# The character name removed is: Mr. Allen, Mast
# The character name removed is: Mr. Higgins, Su
# The character name removed is: Mr. Hogg, Whale
# The character name removed is: Mr. Hollar, Boa
# The character name removed is: William Warley,
# The character name removed is: Bert       (Cre
# The character name removed is: Prison Guard #1
# The character name removed is: Bus Driver - Fl
# The character name removed is: Jackie - New Yo
# The character name removed is: Rich Lady - New
# The character name removed is: Sally Buck - Te
# The character name removed is: Woodsy Niles -
# The character name removed is: Nyah Nordoff-Ha
# The character name removed is: Chien-Po
# The character name removed is: Shan-Yu
# The character name removed is: Reporter #1
# The character name removed is: Day-Day
# The character name removed is: Smokey       (A
# The character name removed is: Anna - Moscow R
# The character name removed is: Fran�Ois Toulou
# The character name removed is: Rob Newhouse -
# The character name removed is: Stan - Chotchki
# The character name removed is: Gunman #3
# The character name removed is: Abu 'Imam' Al-W
# The character name removed is: Bud-Lite Kamins
# The character name removed is: Himself - Radio
# The character name removed is: Tony Janiro - J
# The character name removed is: Alyssa Craig (1
# The character name removed is: Chairman / Doct
# The character name removed is: Mr. Blonde - Vi
# The character name removed is: Mr. Orange - Fr
# The character name removed is: Mr. White - Lar
# The character name removed is: Alan 'Yeah-Yeah
# The character name removed is: T-4 Medic Wade
# The character name removed is: Adam Faulkner-S
# The character name removed is: Detective #2
# The character name removed is: Dead Man At 1St
# The character name removed is: Zo�
# The character name removed is: Makepeace - The
# The character name removed is: Peter - The Sta
# The character name removed is: Tilney - Master
# The character name removed is: 1946 D.A.
# The character name removed is: Forest Ranger #
# The character name removed is: Evelyn Berman-S
# The character name removed is: Bernard, Lawyer
# The character name removed is: Mary, Claire'S
# The character name removed is: C-3Po
# The character name removed is: Ki-Adi-Mundi /
# The character name removed is: Obi-Wan Kenobi
# The character name removed is: Ben (Obi-Wan) K
# The character name removed is: C-3Po
# The character name removed is: Obi-Wan Kenobi
# The character name removed is: Qui-Gon Jinn
# The character name removed is: Ric Oli�
# The character name removed is: Amy (Segment "F
# The character name removed is: Catherine (Segm
# The character name removed is: Consuelo (Segme
# The character name removed is: Elli (Segment "
# The character name removed is: Esposito (Segme
# The character name removed is: Ethan (Segment
# The character name removed is: Marcus (Segment
# The character name removed is: Mr. Demarco (Se
# The character name removed is: Stanley (Segmen
# The character name removed is: Toby Oxman (Seg
# The character name removed is: Toby'S Editor (
# The character name removed is: Vi (Segment "Fi
# The character name removed is: 1St Cop
# The character name removed is: Paula Datzman-M
# The character name removed is: Kara Zor-El
# The character name removed is: Emir Hamed Al-S
# The character name removed is: Peter Smith-Kin
# The character name removed is: Andy - Gun Sale
# The character name removed is: Tami-Lynn
# The character name removed is: Lena, The Waitr
# The character name removed is: Friend #3
# The character name removed is: Debbie Barlow,
# The character name removed is: Jim - The Docto
# The character name removed is: Megan - The Doc
# The character name removed is: Elvis, Alabama'
# The character name removed is: Floyd - Dick'S
# The character name removed is: Lobby Cop #1
# The character name removed is: Ren�E
# The character name removed is: Biker #1
# The character name removed is: Major-General H
# The character name removed is: Cop #1
# The character name removed is: Aide #1
# The character name removed is: Guard #1
# The character name removed is: Chet       (Sce
# The character name removed is: Red       (Scen
# The character name removed is: Nicky Koskoff (
# The character name removed is: Newscaster #1
# The character name removed is: Sailor #1
# The character name removed is: Justin - Devgru
# The character name removed is: Patrick - Squad
# The character name removed is: Saber - Devgru
# The character name removed is: Stayne - Knave
# The character name removed is: Briony Tallis,
# The character name removed is: Miriam Grant-Pa
# The character name removed is: The 2Nd Mrs. P
# The character name removed is: Reporter #1
# The character name removed is: Fr�Ulein Kost
# The character name removed is: Sullivan - Cour
# The character name removed is: Tito (4 Yrs.)
# The character name removed is: Caf� Customer
# The character name removed is: Guillaume Bl�Ro
# The character name removed is: Cop - Roosevelt
# The character name removed is: Himself - Tv Re
# The character name removed is: Miss Plumett, C
# The character name removed is: Vice-President
# The character name removed is: Chuck - Beard C
# The character name removed is: Jean-Do
# The character name removed is: Garc�S
# The character name removed is: Dr. Barringer -
# The character name removed is: Tom - President
# The character name removed is: F.B.I. Man #1
# The character name removed is: Senator #1
# The character name removed is: Reporter #1 (Je
# The character name removed is: Beth - Beller'S
# The character name removed is: Sunshine Dor�
# The character name removed is: Mr. Broadman -
# The character name removed is: X-Ray
# The character name removed is: Alma - Maid
# The character name removed is: Judge Hank "The
# The character name removed is: O-Ren Ishii
# The character name removed is: David, 9 Years
# The character name removed is: Hawkeye (Nathan
# The character name removed is: Redcoat #2
# The character name removed is: John, Apostle
# The character name removed is: Martha, Sister
# The character name removed is: Mary, Mother Of
# The character name removed is: Nathaniel, Apos
# The character name removed is: Peter, Apostle
# The character name removed is: 1St Stansfield
# The character name removed is: Clo-Clo
# The character name removed is: Maria - Fortune
# The character name removed is: Roblos - The Po
# The character name removed is: Once-Ler'S Mom
# The character name removed is: The Once-Ler
# The character name removed is: Diana �Lvarez
# The character name removed is: Lucy D�Az
# The character name removed is: Pablo Aristiz�B
# The character name removed is: Mitch, Secret S
# The character name removed is: Mr. Brian, Casi
# The character name removed is: Freese - Attorn
# The character name removed is: 1St Lt. Luke Si
# The character name removed is: Lt. Val "Valent
# The character name removed is: Sgt. Danny "Dan
# The character name removed is: Sgt. Richard "R
# The character name removed is: Mao Tse-Tung
# The character name removed is: Reporter #1
# The character name removed is: Himself       (
# The character name removed is: Delben�
# The character name removed is: Royer-Collard
# The character name removed is: Lawyer (Talon L
# The character name removed is: Mr. Emerson, An
# The character name removed is: Tv Reporter #1
# The character name removed is: Irving August -
# The character name removed is: Jason Hoag - Po
# The character name removed is: Miss Summers -
# The character name removed is: Mrs. Lowood - H
# The character name removed is: Paul Radeaux -
# The character name removed is: Otb Man #1, Tom
# The character name removed is: Otb Man #2, Jer
# The character name removed is: Guard #1
# The character name removed is: B-4
# The character name removed is: Jean-Luc Picard
# The character name removed is: Bee-Bee
# The character name removed is: Jake - Slater M
# The character name removed is: 2Nd Officer Lig
# The character name removed is: Dan Campbell, T
# The character name removed is: Fran�Ois Filiba
# The character name removed is: Jacques, Mariet
# The character name removed is: Kevin, Teenager
# The character name removed is: James - Max'S B
# The character name removed is: Ben Cappadora -
# The character name removed is: Nurse #1
# The character name removed is: Cynthia - Massa
# The character name removed is: Mamie-Claire
# The character name removed is: Carrie-Ann
# The character name removed is: Shirley, Sunnys
# The character name removed is: Lisa Brennan (1
# The character name removed is: Lord Portley-Ri
# The character name removed is: Winnie Portley-
# The character name removed is: Lois, Social Wo
# The character name removed is: Miss Briscoe, S
# The character name removed is: Senior Doctor -
# The character name removed is: Niki Trumbo (Ag
# The character name removed is: Iqbal - The Dri
# The character name removed is: Adele Bloch-Bau
# The character name removed is: Therese Bloch-B
# The character name removed is: Hades; Lord Of
# The character name removed is: Hermes; The Mes
# The character name removed is: Am�Lie Poulain
# The character name removed is: Alicate - Clipp
# The character name removed is: Barbantinho - S
# The character name removed is: Ben� - Benny
# The character name removed is: Berenice - Bern
# The character name removed is: Buscap� - Rocke
# The character name removed is: Cabe��O - Melon
# The character name removed is: Cabeleira - Sha
# The character name removed is: Dadinho - Li'L
# The character name removed is: Jab�
# The character name removed is: Man� Galinha -
# The character name removed is: Marreco - Goose
# The character name removed is: Ot�Vio
# The character name removed is: Thiago - Tiago
# The character name removed is: Z� Pequeno - Li
# The character name removed is: Toot-Toot
# The character name removed is: Eddie Scrap-Iro
# The character name removed is: Ref #1
# The character name removed is: Karl - Harry'S
# The character name removed is: 1982 Championsh
# The character name removed is: Elise Clifton-W
# The character name removed is: Mary Heller-Van
# The character name removed is: Magda Rees-Jone
# The character name removed is: Stuart, Bannist
# The character name removed is: Abby (Segment "
# The character name removed is: Cherry (Segment
# The character name removed is: Dr. Felix (Segm
# The character name removed is: Earl Mcgraw (Se
# The character name removed is: Jt (Segment "Pl
# The character name removed is: Muldoon (Segmen
# The character name removed is: Rapist #1 (Segm
# The character name removed is: Skip (Segment "
# The character name removed is: Wray (Segment "
# The character name removed is: Henri-Anne
# The character name removed is: 9
# The character name removed is: Soldier #2
# The character name removed is: Grady 'Coon-Ass
# The character name removed is: Pooter-The-Clow
# The character name removed is: Hannibal 8Yrs
# The character name removed is: Barth�L�My
# The character name removed is: Chun-Li
# The character name removed is: Chun-Li
# The character name removed is: Olive (4 Years
# The character name removed is: Ma-Ma
# The character name removed is: 2Nd Lieutenant
# The character name removed is: Ho-Jon
# The character name removed is: Cass Blaine (Se
# The character name removed is: Jordy Verrill (
# The character name removed is: Upson Pratt (Se
# The character name removed is: White (Segment
# The character name removed is: Al-Saleem
# The character name removed is: Army-Jacket
# The character name removed is: Andr� Petrescu
# The character name removed is: Jean-Pierre
# The character name removed is: Brogan-Moore
# The character name removed is: Jane Winslett-R
# The character name removed is: Dr. Shrink-Rom
# The character name removed is: Jean-Claude
# The character name removed is: St-Clair
# The character name removed is: Sarah, George'S
# The character name removed is: Trooper #1
# The character name removed is: Larry "Doc" Spo
# The character name removed is: Sauncho Smilax,
# The character name removed is: Bassist (Nassau
# The character name removed is: Judge (39)
# The character name removed is: Anna Howland-Jo
# The character name removed is: 2Nd Lieut. Jerr
# The character name removed is: 2Nd Lieut. Mart
# The character name removed is: James Reston, J
# The character name removed is: Elmer - Jason'S
# The character name removed is: Josephine (Joey
# The character name removed is: Anna - Housekee
# The character name removed is: Charley - Chica
# The character name removed is: Moon (The Kid)
# The character name removed is: Two-Bit Matthew
# The character name removed is: Robert Dudley,
# The character name removed is: Waad, Chancello
# The character name removed is: Justice #1
# The character name removed is: Detective #2
# The character name removed is: John "Doc" Brad
# The character name removed is: Ralph "Iggy" Ig
# The character name removed is: Ray (Old Caddy)
# The character name removed is: Prom Goers - Ol
# The character name removed is: Cop #1
# The character name removed is: Saso (Ron)
# The character name removed is: Hugo Fraser-Tyr
# The character name removed is: James Leighton-
# The character name removed is: Goat-Winston
# The character name removed is: Terp #1
# The character name removed is: Hold-Up Man
# The character name removed is: Trevor "Broom"
# The character name removed is: 1St Lt. Dobbs
# The character name removed is: 1St Lt. Milo Mi
# The character name removed is: Beirut: Doumet
# The character name removed is: Pablo & Pedro C
# The character name removed is: Bill Lawson - N
# The character name removed is: Migrant #1
# The character name removed is: Mrs. Keeper, Th
# The character name removed is: Eazy-E
# The character name removed is: Bill Jarvis, Fr
# The character name removed is: Tia To�A
# The character name removed is: Policeman #1
# The character name removed is: Commentator #1
# The character name removed is: Zachary Lamb -
# The character name removed is: Freshman Girl #
# The character name removed is: Er Doctor #1
# The character name removed is: James P. "Sulle
# The character name removed is: Santa Family #1
# The character name removed is: Clark, Sr.
# The character name removed is: Francis Sheehy-
# The character name removed is: Doctor - Vietna
# The character name removed is: Donna, Ron'S Gi
# The character name removed is: Young Radical -
# The character name removed is: Fbi Agent #1
# The character name removed is: G�Nther Bachman
# The character name removed is: Bala-Tik
# The character name removed is: C-3Po
# The character name removed is: Chief Two-Tongu
# The character name removed is: Society Lady #1
# The character name removed is: Trooper #1
# The character name removed is: Newscaster (O
# The character name removed is: Tour Manager -
# The character name removed is: Do�A Alfonsa
# The character name removed is: Dean "Mf" Jones
# The character name removed is: Brother-In-Law
# The character name removed is: Maria, Dr. Mott
# The character name removed is: Roth, The Schoo
# The character name removed is: Presenter #1
# The character name removed is: The Well-Manicu
# The character name removed is: Bodyguard #1
# The character name removed is: Benigno Mart�N
# The character name removed is: Lydia Gonz�Lez
# The character name removed is: Liza, Wendy'S H
# The character name removed is: Anne-Marie Mcco
# The character name removed is: Lord Johnson-Jo
# The character name removed is: Kevin Branson -
# The character name removed is: Tug Kowalski -
# The character name removed is: Sonmi-451
# The character name removed is: Tomar-Re
# The character name removed is: Hyena-Swine
# The character name removed is: Salvador Dal�
# The character name removed is: Dr. Wexler - Ma
# The character name removed is: Julie - Associa
# The character name removed is: Tony - Andreas'
# The character name removed is: Greta Schr�Der
# The character name removed is: College-Aged Bi
# The character name removed is: 1St Lt. Band
# The character name removed is: 1St Sgt. Edward
# The character name removed is: 2Nd Lt. Gore
# The character name removed is: Medic #2
# The character name removed is: Pfc - Beade
# The character name removed is: Groomsman #5
# The character name removed is: Doctor #1

# %%
print(df_films.shape)
# Out:
# (22470, 14)

# %% [markdown]
# After cleaning the number of rows is 22470

# %% [markdown]
# #### The approach I used to clean up the character column of df_films:

# %% [markdown]
# 1. Initially, we remove rows with missing values from the 'character' column using the dropna() method.
# 2. This function clean_character_name takes a character name as input and returns a cleaned version of the name.
# 3.
# It first checks if the name matches a valid pattern containing letters, spaces, periods, and apostrophes
# 4.
# If the name doesn't match the valid pattern, io extrasct a meaningful name using a regular expression pattern that looks for a word (sequence of letters) followed by optional spaces and digit
# 5. .
# If a meaningful name can be extracted, it returns that name; otherwise, it returns No.
